# %%
import requests
from bs4 import BeautifulSoup
from IPython.display import Markdown, display
import ollama

# %%
MODEL = "llama3.2"

# %%
messages = [{"role" : "user" , "content" : "Describe some of the buisness application of the Gen Ai"}]

# %%
class Website:
    url : str
    title : str
    text : str

    def __init__(self, url):
        self.url = url
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        self.title = soup.title.string if soup.title else "NO title found"
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()
        self.text = soup.body.get_text(separator="\n", strip=True)

# %%
ed = Website("https://www.geeksforgeeks.org/python-programming-language-tutorial/")
print(ed.title)
print(ed.text)
# Out:
# Python Tutorial | Learn Python Programming Language
# Skip to content
# Courses
# Get IBM Certifications
# Complete Machine Learning & Data Science Program
# Data Science Training Program
# Data Analytics Training using Excel, SQL, Python & PowerBI
# Complete Data Analytics Program
# DSA to Development
# For Working Professionals
# Data Structure & Algorithm Classes (Live)
# System Design (Live)
# JAVA Backend Development(Live)
# DevOps(Live)
# Data Structures & Algorithms in Python
# For Students
# Interview Preparation Course
# GATE CS & IT 2025
# Data Science (Live)
# Data Structure & Algorithm-Self Paced(C++/JAVA)
# Master Competitive Programming(Live)
# Full Stack Development with React & Node JS(Live)
# All Courses
# Full Stack Development
# Data Science Program
# Tutorials
# Python Tutorial
# Taking Input in Python
# Python Operators
# Python Variables
# Data Types
# Loops in Python
# Python Functions
# Python OOPS Concept
# DSA in Python
# Python Exercises
# ...

# %%
system_prompt = "You are an assistant that analyzes the contents of a website \
and provides a short summary, ignoring text that might be navigation related. \
Respond in markdown."

# %%
def user_prompt_for(website):
    user_prompt = f"You are looking at a website titled {website.title}"
    user_prompt += "The contents of this website is as follows; \
please provide a short summary of this website in markdown. \
If it includes news or announcements, then summarize these too.\n\n"
    user_prompt += website.text
    return user_prompt

# %%
def messages_for(website):
    return [
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": user_prompt_for(website)}
    ]

# %%
def summarize(url):
    website = Website(url)
    messages = messages_for(website)
    response = ollama.chat(model=MODEL, messages=messages)
    return response['message']['content']

# %%
summarize("https://www.geeksforgeeks.org/python-programming-language-tutorial/")
# Out:
# 'Here\'s a suggested improvement for the article:\n\n**Title:** "Unlock Your Potential with GeeksforGeeks: A Comprehensive Guide to Learning and Growing"\n\n**Introduction:**\n\nWelcome to GeeksforGeeks, your ultimate destination for learning and growing in the world of technology. As a community-driven platform, we strive to provide high-quality resources and support to help you achieve your goals. Whether you\'re a beginner or an expert, our content is designed to inspire, educate, and motivate you to reach new heights.\n\n**What We Offer:**\n\nAt GeeksforGeeks, we offer a wide range of resources to cater to different learning styles and needs. From tutorials and guides to practice problems and puzzles, our content covers everything from basic programming concepts to advanced topics in machine learning, data science, and more.\n\n**Our Expert Team:**\n\nOur team of experts, including experienced professionals and educators, is dedicated to creating high-quality content that meets y
# ...

# %%
def display_summary(url):
    summary = summarize(url)
    display(Markdown(summary))

# %%
display_summary("https://www.geeksforgeeks.org/python-programming-language-tutorial/")
# Out:
# Here is a comprehensive list of topics and resources related to Python programming for beginners:
#
# **Topics:**
#
# 1. **Introduction to Python**: What is Python? Why learn Python?
# 2. **Basic Syntax**: Variables, Data Types, Operators
# 3. **Control Structures**: If-Else Statements, Loops (For, While)
# 4. **Functions**: Defining and calling functions
# 5. **Modules and Packages**: Importing and using external libraries
# 6. **File Input/Output**: Reading and writing files
# 7. **Data Structures**: Lists, Tuples, Dictionaries, Sets
# 8. **Object-Oriented Programming (OOP)**: Classes, Objects, Inheritance
# 9. **Exception Handling**: Try-Except Blocks, Raising and Catching exceptions
# 10. **Advanced Topics**: Regular Expressions, Decorators
#
# **Resources:**
#
# 1. **Official Python Documentation**: [docs.python.org](http://docs.python.org)
# 2. **Python Tutorial by Google**: [developers.google.com/edu/python](http://developers.google.com/edu/python)
# ...

# %%
display_summary("https://dashboard.masaischool.com/entrence-test?course=IIT_MANDI_CSE_29_DEC_24")
# Out:
# # Website Summary: Masai School Login
#
# ### Overview
# The Masai School Login website appears to be an online platform for students and staff to access various resources and services related to the Masai school.
#
# ### Key Features
#
# *   **Single Sign-On (SSO) System**: The website mentions that JavaScript needs to be enabled to run the app, suggesting a SSO system to manage user authentication.
# *   **Secure Portal**: The login page suggests a secure portal for accessing sensitive information and resources.
#
# ### News and Announcements
# Unfortunately, there are no news or announcements provided on this website.

# %%
display_summary("https://sp.srmist.edu.in/srmiststudentportal/students/loginManager/youLogin.jsp")
# Out:
# **Summary of SRM Student Portal Website**
# ...
#
# The SRM Student Portal is a centralized online platform for students to access their academic and financial information. The portal allows students to log in using their NetID credentials, which can be obtained by registering an email address with the `@srmist.edu.in` domain.
#
# **Key Features**
#
# * Access to academic and financial details
# * Login functionality using NetID credentials
#
# **Login Process**
# -----------------
#
# 1. Enter NetID (without `@srmist.edu.in`)
# 2. Enter User ID
# 3. Enter Password
# 4. Enter Captcha
# 5. Click "Login"
# 6. User Credentials will be confirmed, with an option to save user credentials for future login.
#
# **Additional Options**
#
# * Forgot password? - a feature to reset or recover forgotten passwords.
# * Wish to get your user credentials? - a feature to automatically log in with saved credentials.
# * Close - a feature to exit the login process.
